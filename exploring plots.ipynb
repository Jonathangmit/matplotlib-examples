# %% [markdown]
# # Exploring plots
#
# ***

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
plt.style.use("ggplot")

# %%
plt.plot([1,2,3],"r-",label = "red line")
plt.legend()

# %%
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3],"r-",label = "red line")
ax.legend()

# %%
#### from seaborn

# %%
x = [1,2,3,4]
y = [1,2,3,4]
print(x)
print(y)
type(x)
sns.relplot(x=x, y=y);
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0878151f30d2> in <module>
#       4 print(y)
#       5 type(x)
# ----> 6 sns.relplot(x=x, y=y);
#
# NameError: name 'sns' is not defined

# %%
x = np.linspace(1, 100, 5)
y = x**2
print(x)
print(y)
plt.plot(x,y);
sns.relplot(x,y);
# Out:
# [  1.    25.75  50.5   75.25 100.  ]
# [1.0000000e+00 6.6306250e+02 2.5502500e+03 5.6625625e+03 1.0000000e+04]
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x = np.linspace(0.0,100.0,40)
y=x**2+np.random.normal(0,1000,len(x))
sns.relplot(x=x,y=y);

# %%
x = np.random.normal(1,2,10)
x
# Out:
# array([ 3.62303873,  2.12402169, -2.24932296,  0.41412226,  3.56136914,
#        -0.52003564, -1.04120926,  0.95488197,  5.0949621 ,  0.07007416])

# %%
sns.displot(x, kde=True)

# %%
makes = ["toyota","skoda","VW","BMW"]
car=np.random.choice(makes,1000)

# %%
sns.countplot(x=car)
